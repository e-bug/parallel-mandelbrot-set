# %%
import plotting

# %% [markdown]
# ## Average number of iterations per pixels as a function of the image size

# %%
n_pxs = [589824, 746496, 1049088, 1440000, 2073600, 3686400, 8294400]
avgiters = [221.155073, 221.118321, 221.084885, 221.091267, 221.102072, 221.059687, 221.069069]
all_avgs = [avgiters]
all_labels = ['589824\n(1024x576)', '746496\n(1152x648)', '921600\n(1280x720)', '1049088\n(1366x768)', 
              '1440000\n(1600x900)', '2073600\n(1920x1080)', '3686400\n(2560x1440)', '8294400\n(3840x2160)']

# %%
plotting.plot_tts(n_pxs, all_avgs, xscale='log2', yscale=None, 
                  labels=['1000'], legend_title='max_iteration', 
                  xlabel='Number of pixels', ylabel='Average number of iterations')

# %% [markdown]
# ## Average number of iterations per pixels as a function of max_iteration

# %%
n_pxs = [10, 100, 1000, 10000, 100000, 100000]
avgiters = [211.956852, 220.911833, 221.102072, 221.112125, 221.103802, 221.103101]
all_avgs = [avgiters]

# %%
plotting.plot_tts(n_pxs, all_avgs, xscale='log', yscale=None, 
                  labels=['2073600'], legend_title='Number of pixels', 
                  xlabel='max_iteration', ylabel='Average number of iterations')
